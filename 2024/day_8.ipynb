# %% [markdown]
# --- Day 8: Resonant Collinearity ---
# You find yourselves on the roof of a top-secret Easter Bunny installation.
#
# While The Historians do their thing, you take a look at the familiar huge antenna. Much to your surprise, it seems to have been reconfigured to emit a signal that makes people 0.1% more likely to buy Easter Bunny brand Imitation Mediocre Chocolate as a Christmas gift! Unthinkable!
#
# Scanning across the city, you find that there are actually many such antennas. Each antenna is tuned to a specific frequency indicated by a single lowercase letter, uppercase letter, or digit. You create a map (your puzzle input) of these antennas. For example:
#
# ............
# ........0...
# .....0......
# .......0....
# ....0.......
# ......A.....
# ............
# ............
# ........A...
# .........A..
# ............
# ............
# The signal only applies its nefarious effect at specific antinodes based on the resonant frequencies of the antennas. In particular, an antinode occurs at any point that is perfectly in line with two antennas of the same frequency - but only when one of the antennas is twice as far away as the other. This means that for any pair of antennas with the same frequency, there are two antinodes, one on either side of them.
#
# So, for these two antennas with frequency a, they create the two antinodes marked with #:
#
# ..........
# ...#......
# ..........
# ....a.....
# ..........
# .....a....
# ..........
# ......#...
# ..........
# ..........
# Adding a third antenna with the same frequency creates several more antinodes. It would ideally add four antinodes, but two are off the right side of the map, so instead it adds only two:
#
# ..........
# ...#......
# #.........
# ....a.....
# ........a.
# .....a....
# ..#.......
# ......#...
# ..........
# ..........
# Antennas with different frequencies don't create antinodes; A and a count as different frequencies. However, antinodes can occur at locations that contain antennas. In this diagram, the lone antenna with frequency capital A creates no antinodes but has a lowercase-a-frequency antinode at its location:
#
# ..........
# ...#......
# #.........
# ....a.....
# ........a.
# .....a....
# ..#.......
# ......A...
# ..........
# ..........
# The first example has antennas with two different frequencies, so the antinodes they create look like this, plus an antinode overlapping the topmost A-frequency antenna:
#
# ......#....#
# ...#....0...
# ....#0....#.
# ..#....0....
# ....0....#..
# .#....A.....
# ...#........
# #......#....
# ........A...
# .........A..
# ..........#.
# ..........#.
# Because the topmost A-frequency antenna overlaps with a 0-frequency antinode, there are 14 total unique locations that contain an antinode within the bounds of the map.
#
# Calculate the impact of the signal. How many unique locations within the bounds of the map contain an antinode?

# %%
import numpy as np

def get_cords(char,grid):
    '''Returns coordinates where char appears in grid'''
    
    cords = []

    # itterate through coordinates in grid
    # if item in coordinates equals char append coordinates to list
    for y in range(0,len(grid)):
        for x in range(0,len(grid[0])):
            
            if grid[y][x] == char:
                
                cords.append((y,x))
                
    return cords

# read in text
grid = np.array([list(line.strip()) for line in open('day8.txt').readlines()])

# get unique characters in grid
chars = []

for line in grid:
    chars.extend(line)

chars = [char for char in chars if char != '.']

u_chars = list(set(chars))

print("U_chars:", u_chars)

sat_cords = []

# for each unique character
for char in u_chars:

    cords = get_cords(char,grid)
    
    # get anchor coordenate
    for r in range(0, len(cords)):
        
        anchor = cords[r]
        
        cut_cords = [cord for cord in cords if cord != anchor]
        
        print('Anchor:', anchor)
        print('Cords:', cut_cords)
    
        # anchor cords
        ya = anchor[0]
            
        xa = anchor[1]
        
        print('ya, xa:', ya, xa)
        
        # get reversed path from anchor to each other coordinate
        for cord in cut_cords:
          
            # non-ancher cords
            yb = cord[0]
            
            xb = cord[1]
            
            # path from anchor to non-anchor
            y_diff = yb - ya
            
            x_diff = xb - xa
            

            #reveresd path
            y_diff = -y_diff
            
            x_diff = -x_diff
            

            # reveresd path coordinate
            y = ya + y_diff
                
            x = xa + x_diff
            
            if (y >= 0) and (y < len(grid)) and (x >= 0) and (x < len(grid[0])):
                
                sat_cords.append((y,x))

len(list(set(sat_cords)))
# Out:
# U_chars: ['I', 'J', 'p', '7', 'm', 'b', 'M', 'S', 'k', '2', 'V', 'A', 'r', 'D', 'X', 'Y', 'o', 'i', 'Q', 'z', '0', '6', '8', 'W', 'j', 'n', 'E', 'v', 'O', 'Z', 'q', '1', 'K', 'C', 'c', 'N', 'R', 'd', 'f', 'B', 'l', 'w', 'a', '5', 'y', 'P', 'e', '4', '9', 'F', '3', 'L', 's', 'x']
# Anchor: (37, 14)
# Cords: [(41, 17), (48, 15)]
# ya, xa: 37 14
# yb, xb: 41 17
# y_diff, x_diff 4 3
# reverse: -4 -3
# Antinode: 33 11
# yb, xb: 48 15
# y_diff, x_diff 11 1
# reverse: -11 -1
# Antinode: 26 13
# Anchor: (41, 17)
# Cords: [(37, 14), (48, 15)]
# ya, xa: 41 17
# yb, xb: 37 14
# y_diff, x_diff -4 -3
# reverse: 4 3
# Antinode: 45 20
# yb, xb: 48 15
# y_diff, x_diff 7 -2
# reverse: -7 2
# Antinode: 34 19
# Anchor: (48, 15)
# Cords: [(37, 14), (41, 17)]
# ya, xa: 48 15
# yb, xb: 37 14
# y_diff, x_diff -11 -1
# reverse: 11 1
# Antinode: 59 16
# yb, xb: 41 17
# y_diff, x_diff -7 2
# reverse: 7 -2
# Antinode: 55 13
# Anchor: (29, 45)
# Cords: [(33, 34), (36, 35), (48, 30)]
# ya, xa: 29 45
# ...

# %%
import numpy as np

def get_cords(char,grid):
    '''Returns coordinates where char appears in grid'''
    
    cords = []

    # itterate through coordinates in grid
    # if item in coordinates equals char append coordinates to list
    for y in range(0,len(grid)):
        for x in range(0,len(grid[0])):
            
            if grid[y][x] == char:
                
                cords.append((y,x))
                
    return cords

# read in text
grid = np.array([list(line.strip()) for line in open('day8.txt').readlines()])

# get unique characters in grid
chars = []

for line in grid:
    chars.extend(line)

chars = [char for char in chars if char != '.']

u_chars = list(set(chars))

print("U_chars:", u_chars)

sat_cords = []

# for each unique character
for char in u_chars:

    cords = get_cords(char,grid)
    
    # get anchor coordenate
    for r in range(0, len(cords)):
        
        anchor = cords[r]
        
        cut_cords = [cord for cord in cords if cord != anchor]
        
        print('Anchor:', anchor)
        print('Cords:', cut_cords)
    
        # anchor cords
        ya = anchor[0]
            
        xa = anchor[1]
        
        print('ya, xa:', ya, xa)
        
        # get reversed path from anchor to each other coordinate
        for cord in cut_cords:
          
            # non-ancher cords
            yb = cord[0]
            
            xb = cord[1]
            
            print('yb, xb:', yb, xb)
            
            # path from anchor to non-anchor
            y_diff = yb - ya
            
            x_diff = xb - xa
            
            print('y_diff, x_diff', y_diff, x_diff)
            #reveresd path
            y_diff = -y_diff
            
            x_diff = -x_diff
            
            print("reverse:", y_diff, x_diff)
            # reveresd path coordinate
            y = ya + y_diff
                
            x = xa + x_diff
            
            print("Antinode:", y, x)
            
            if (y >= 0) and (y < len(grid)) and (x >= 0) and (x < len(grid[0])):
                
                sat_cords.append((y,x))

len(list(set(sat_cords)))
